# %%
import pandas as pd
df = pd.read_csv("nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 31

# %%
columns
# Out:
# 11

# %%
df.head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df.tail(5)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df[2:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.Temperature #df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
type(df['Events'])
# Out:
# pandas.core.series.Series

# %%
df[['Temperature','Events']]
# Out:
#     Temperature    Events
# 0            38       NaN
# 1            36       NaN
# 2            40       NaN
# 3            25       NaN
# 4            20       NaN
# 5            33       NaN
# 6            39       NaN
# 7            39       NaN
# 8            44      Rain
# 9            50      Rain
# 10           33       NaN
# 11           35       NaN
# 12           26       NaN
# 13           30       NaN
# 14           43       NaN
# 15           47      Rain
# 16           36  Fog-Snow
# 17           25      Snow
# 18           22       NaN
# 19           32       NaN
# 20           31       NaN
# 21           26      Snow
# 22           26  Fog-Snow
# 23           28      Snow
# 24           34       NaN
# 25           43       NaN
# 26           41      Rain
# 27           37       NaN
# 28           36       NaN
# 29           34       NaN
# 30           46       NaN

# %%
df['Temperature'].max()
# Out:
# np.int64(50)

# %%
df['Temperature'].mean()
# Out:
# np.float64(34.67741935483871)

# %%
df['Temperature'].std()
# Out:
# np.float64(7.639315400279416)

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# 50%          10.000000      6.500000    3.000000      281.000000
# 75%          10.000000      8.000000    4.500000      300.000000
# max          10.000000     16.000000    8.000000      345.000000

# %%
 df[df.Temperature>=40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2    1/3/2016           40        21        47                 29.86
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2                10           8.0               0           1    NaN
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# 25               10           7.0               0           2    NaN
# 26               10           7.0               T           3   Rain
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 2              277
# 8               76
# 9              109
# 14             101
# 15             340
# 25             244
# 26             311
# 30             241

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df[df.Temperature==df['Temperature'].max()] #if space
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df[['EST','Temperature']][df.Temperature==df['Temperature'].max()]
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.set_index('EST')
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# 1/14/2016           30        12        47                 29.95
# 1/15/2016           43        31        62                 29.82
# 1/16/2016           47        37        70                 29.52
# 1/17/2016           36        23        66                 29.78
# 1/18/2016           25         6        53                 29.83
# 1/19/2016           22         3        42                 30.03
# 1/20/2016           32        15        49                 30.13
# 1/21/2016           31        11        45                 30.15
# 1/22/2016           26         6        41                 30.21
# 1/23/2016           26        21        78                 29.77
# 1/24/2016           28        11        53                 29.92
# 1/25/2016           34        18        54                 30.25
# 1/26/2016           43        29        56                 30.03
# 1/27/2016           41        22        45                 30.03
# 1/28/2016           37        20        51                 29.90
# 1/29/2016           36        21        50                 29.58
# 1/30/2016           34        16        46                 30.01
# 1/31/2016           46        28        52                 29.90
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# EST
# 1/1/2016                10           8.0               0           5
# 1/2/2016                10           7.0               0           3
# 1/3/2016                10           8.0               0           1
# 1/4/2016                10           9.0               0           3
# 1/5/2016                10           5.0               0           0
# 1/6/2016                10           4.0               0           0
# 1/7/2016                10           2.0               0           3
# 1/8/2016                10           4.0               0           8
# 1/9/2016                 9           8.0               T           8
# 1/10/2016                4           NaN             1.8           7
# 1/11/2016               10           NaN               0           1
# 1/12/2016               10           6.0               T           4
# 1/13/2016               10          10.0               0           0
# 1/14/2016               10           5.0               T           7
# 1/15/2016                9           5.0               T           2
# 1/16/2016                8           7.0            0.24           7
# 1/17/2016                8           6.0            0.05           6
# 1/18/2016                9          12.0               T           2
# 1/19/2016               10          11.0               0           1
# 1/20/2016               10           6.0               0           2
# 1/21/2016               10           6.0               0           1
# 1/22/2016                9           NaN            0.01           3
# 1/23/2016                1          16.0            2.31           8
# 1/24/2016                8           6.0               T           3
# 1/25/2016               10           3.0               0           2
# 1/26/2016               10           7.0               0           2
# 1/27/2016               10           7.0               T           3
# 1/28/2016               10           5.0               0           1
# 1/29/2016               10           8.0               0           4
# 1/30/2016               10           7.0               0           0
# 1/31/2016               10           5.0               0           0
#
#              Events  WindDirDegrees
# EST
# 1/1/2016        NaN             281
# 1/2/2016        NaN             275
# 1/3/2016        NaN             277
# 1/4/2016        NaN             345
# 1/5/2016        NaN             333
# 1/6/2016        NaN             259
# 1/7/2016        NaN             293
# 1/8/2016        NaN              79
# 1/9/2016       Rain              76
# 1/10/2016      Rain             109
# 1/11/2016       NaN             289
# 1/12/2016       NaN             235
# 1/13/2016       NaN             284
# 1/14/2016       NaN             266
# 1/15/2016       NaN             101
# 1/16/2016      Rain             340
# 1/17/2016  Fog-Snow             345
# 1/18/2016      Snow             293
# 1/19/2016       NaN             293
# 1/20/2016       NaN             302
# 1/21/2016       NaN             312
# 1/22/2016      Snow              34
# 1/23/2016  Fog-Snow              42
# 1/24/2016      Snow             327
# 1/25/2016       NaN             286
# 1/26/2016       NaN             244
# 1/27/2016      Rain             311
# 1/28/2016       NaN             234
# 1/29/2016       NaN             298
# 1/30/2016       NaN             257
# 1/31/2016       NaN             241

# %%
df.loc['1/24/2016']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df.loc['1/24/2016']
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: '1/24/2016'

# %%
df.set_index('EST', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/z4/sqpgvldj0m31m5vm_t67ly3r0000gn/T/ipykernel_43142/562225329.py in ?()
# ----> 1 df.set_index('EST', inplace=True)
#
# ~/myenv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['EST'] are in the columns"

# %%
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# 1/14/2016           30        12        47                 29.95
# 1/15/2016           43        31        62                 29.82
# 1/16/2016           47        37        70                 29.52
# 1/17/2016           36        23        66                 29.78
# 1/18/2016           25         6        53                 29.83
# 1/19/2016           22         3        42                 30.03
# 1/20/2016           32        15        49                 30.13
# 1/21/2016           31        11        45                 30.15
# 1/22/2016           26         6        41                 30.21
# 1/23/2016           26        21        78                 29.77
# 1/24/2016           28        11        53                 29.92
# 1/25/2016           34        18        54                 30.25
# 1/26/2016           43        29        56                 30.03
# 1/27/2016           41        22        45                 30.03
# 1/28/2016           37        20        51                 29.90
# 1/29/2016           36        21        50                 29.58
# 1/30/2016           34        16        46                 30.01
# 1/31/2016           46        28        52                 29.90
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# EST
# 1/1/2016                10           8.0               0           5
# 1/2/2016                10           7.0               0           3
# 1/3/2016                10           8.0               0           1
# 1/4/2016                10           9.0               0           3
# 1/5/2016                10           5.0               0           0
# 1/6/2016                10           4.0               0           0
# 1/7/2016                10           2.0               0           3
# 1/8/2016                10           4.0               0           8
# 1/9/2016                 9           8.0               T           8
# 1/10/2016                4           NaN             1.8           7
# 1/11/2016               10           NaN               0           1
# 1/12/2016               10           6.0               T           4
# 1/13/2016               10          10.0               0           0
# 1/14/2016               10           5.0               T           7
# 1/15/2016                9           5.0               T           2
# 1/16/2016                8           7.0            0.24           7
# 1/17/2016                8           6.0            0.05           6
# 1/18/2016                9          12.0               T           2
# 1/19/2016               10          11.0               0           1
# 1/20/2016               10           6.0               0           2
# 1/21/2016               10           6.0               0           1
# 1/22/2016                9           NaN            0.01           3
# 1/23/2016                1          16.0            2.31           8
# 1/24/2016                8           6.0               T           3
# 1/25/2016               10           3.0               0           2
# 1/26/2016               10           7.0               0           2
# 1/27/2016               10           7.0               T           3
# 1/28/2016               10           5.0               0           1
# 1/29/2016               10           8.0               0           4
# 1/30/2016               10           7.0               0           0
# 1/31/2016               10           5.0               0           0
#
#              Events  WindDirDegrees
# EST
# 1/1/2016        NaN             281
# 1/2/2016        NaN             275
# 1/3/2016        NaN             277
# 1/4/2016        NaN             345
# 1/5/2016        NaN             333
# 1/6/2016        NaN             259
# 1/7/2016        NaN             293
# 1/8/2016        NaN              79
# 1/9/2016       Rain              76
# 1/10/2016      Rain             109
# 1/11/2016       NaN             289
# 1/12/2016       NaN             235
# 1/13/2016       NaN             284
# 1/14/2016       NaN             266
# 1/15/2016       NaN             101
# 1/16/2016      Rain             340
# 1/17/2016  Fog-Snow             345
# 1/18/2016      Snow             293
# 1/19/2016       NaN             293
# 1/20/2016       NaN             302
# 1/21/2016       NaN             312
# 1/22/2016      Snow              34
# 1/23/2016  Fog-Snow              42
# 1/24/2016      Snow             327
# 1/25/2016       NaN             286
# 1/26/2016       NaN             244
# 1/27/2016      Rain             311
# 1/28/2016       NaN             234
# 1/29/2016       NaN             298
# 1/30/2016       NaN             257
# 1/31/2016       NaN             241

# %%
df.loc['1/24/2016']
# Out:
# Temperature                28
# DewPoint                   11
# Humidity                   53
# Sea Level PressureIn    29.92
# VisibilityMiles             8
# WindSpeedMPH              6.0
# PrecipitationIn             T
# CloudCover                  3
# Events                   Snow
# WindDirDegrees            327
# Name: 1/24/2016, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 0         0      0   1/1/2016           38        23        52
# 1         1      1   1/2/2016           36        18        46
# 2         2      2   1/3/2016           40        21        47
# 3         3      3   1/4/2016           25         9        44
# 4         4      4   1/5/2016           20        -3        41
# 5         5      5   1/6/2016           33         4        35
# 6         6      6   1/7/2016           39        11        33
# 7         7      7   1/8/2016           39        29        64
# 8         8      8   1/9/2016           44        38        77
# 9         9      9  1/10/2016           50        46        71
# 10       10     10  1/11/2016           33         8        37
# 11       11     11  1/12/2016           35        15        53
# 12       12     12  1/13/2016           26         4        42
# 13       13     13  1/14/2016           30        12        47
# 14       14     14  1/15/2016           43        31        62
# 15       15     15  1/16/2016           47        37        70
# 16       16     16  1/17/2016           36        23        66
# 17       17     17  1/18/2016           25         6        53
# 18       18     18  1/19/2016           22         3        42
# 19       19     19  1/20/2016           32        15        49
# 20       20     20  1/21/2016           31        11        45
# 21       21     21  1/22/2016           26         6        41
# 22       22     22  1/23/2016           26        21        78
# 23       23     23  1/24/2016           28        11        53
# 24       24     24  1/25/2016           34        18        54
# 25       25     25  1/26/2016           43        29        56
# 26       26     26  1/27/2016           41        22        45
# 27       27     27  1/28/2016           37        20        51
# 28       28     28  1/29/2016           36        21        50
# 29       29     29  1/30/2016           34        16        46
# 30       30     30  1/31/2016           46        28        52
#
#     Sea Level PressureIn  VisibilityMiles  WindSpeedMPH PrecipitationIn  \
# 0                  30.03               10           8.0               0
# 1                  30.02               10           7.0               0
# 2                  29.86               10           8.0               0
# 3                  30.05               10           9.0               0
# 4                  30.57               10           5.0               0
# 5                  30.50               10           4.0               0
# 6                  30.28               10           2.0               0
# 7                  30.20               10           4.0               0
# 8                  30.16                9           8.0               T
# 9                  29.59                4           NaN             1.8
# 10                 29.92               10           NaN               0
# 11                 29.85               10           6.0               T
# 12                 29.94               10          10.0               0
# 13                 29.95               10           5.0               T
# 14                 29.82                9           5.0               T
# 15                 29.52                8           7.0            0.24
# 16                 29.78                8           6.0            0.05
# 17                 29.83                9          12.0               T
# 18                 30.03               10          11.0               0
# 19                 30.13               10           6.0               0
# 20                 30.15               10           6.0               0
# 21                 30.21                9           NaN            0.01
# 22                 29.77                1          16.0            2.31
# 23                 29.92                8           6.0               T
# 24                 30.25               10           3.0               0
# 25                 30.03               10           7.0               0
# 26                 30.03               10           7.0               T
# 27                 29.90               10           5.0               0
# 28                 29.58               10           8.0               0
# 29                 30.01               10           7.0               0
# 30                 29.90               10           5.0               0
#
#     CloudCover    Events  WindDirDegrees
# 0            5       NaN             281
# 1            3       NaN             275
# 2            1       NaN             277
# 3            3       NaN             345
# 4            0       NaN             333
# 5            0       NaN             259
# 6            3       NaN             293
# 7            8       NaN              79
# 8            8      Rain              76
# 9            7      Rain             109
# 10           1       NaN             289
# 11           4       NaN             235
# 12           0       NaN             284
# 13           7       NaN             266
# 14           2       NaN             101
# 15           7      Rain             340
# 16           6  Fog-Snow             345
# 17           2      Snow             293
# 18           1       NaN             293
# 19           2       NaN             302
# 20           1       NaN             312
# 21           3      Snow              34
# 22           8  Fog-Snow              42
# 23           3      Snow             327
# 24           2       NaN             286
# 25           2       NaN             244
# 26           3      Rain             311
# 27           1       NaN             234
# 28           4       NaN             298
# 29           0       NaN             257
# 30           0       NaN             241

# %%
df.set_index('Temperature',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/z4/sqpgvldj0m31m5vm_t67ly3r0000gn/T/ipykernel_43142/3013821085.py in ?()
# ----> 1 df.set_index('Temperature',inplace=True)
#       2 df
#
# ~/myenv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Temperature'] are in the columns"

# %%
df
# Out:
#              level_0  index        EST  DewPoint  Humidity  \
# Temperature
# 38                 0      0   1/1/2016        23        52
# 36                 1      1   1/2/2016        18        46
# 40                 2      2   1/3/2016        21        47
# 25                 3      3   1/4/2016         9        44
# 20                 4      4   1/5/2016        -3        41
# 33                 5      5   1/6/2016         4        35
# 39                 6      6   1/7/2016        11        33
# 39                 7      7   1/8/2016        29        64
# 44                 8      8   1/9/2016        38        77
# 50                 9      9  1/10/2016        46        71
# 33                10     10  1/11/2016         8        37
# 35                11     11  1/12/2016        15        53
# 26                12     12  1/13/2016         4        42
# 30                13     13  1/14/2016        12        47
# 43                14     14  1/15/2016        31        62
# 47                15     15  1/16/2016        37        70
# 36                16     16  1/17/2016        23        66
# 25                17     17  1/18/2016         6        53
# 22                18     18  1/19/2016         3        42
# 32                19     19  1/20/2016        15        49
# 31                20     20  1/21/2016        11        45
# 26                21     21  1/22/2016         6        41
# 26                22     22  1/23/2016        21        78
# 28                23     23  1/24/2016        11        53
# 34                24     24  1/25/2016        18        54
# 43                25     25  1/26/2016        29        56
# 41                26     26  1/27/2016        22        45
# 37                27     27  1/28/2016        20        51
# 36                28     28  1/29/2016        21        50
# 34                29     29  1/30/2016        16        46
# 46                30     30  1/31/2016        28        52
#
#              Sea Level PressureIn  VisibilityMiles  WindSpeedMPH  \
# Temperature
# 38                          30.03               10           8.0
# 36                          30.02               10           7.0
# 40                          29.86               10           8.0
# 25                          30.05               10           9.0
# 20                          30.57               10           5.0
# 33                          30.50               10           4.0
# 39                          30.28               10           2.0
# 39                          30.20               10           4.0
# 44                          30.16                9           8.0
# 50                          29.59                4           NaN
# 33                          29.92               10           NaN
# 35                          29.85               10           6.0
# 26                          29.94               10          10.0
# 30                          29.95               10           5.0
# 43                          29.82                9           5.0
# 47                          29.52                8           7.0
# 36                          29.78                8           6.0
# 25                          29.83                9          12.0
# 22                          30.03               10          11.0
# 32                          30.13               10           6.0
# 31                          30.15               10           6.0
# 26                          30.21                9           NaN
# 26                          29.77                1          16.0
# 28                          29.92                8           6.0
# 34                          30.25               10           3.0
# 43                          30.03               10           7.0
# 41                          30.03               10           7.0
# 37                          29.90               10           5.0
# 36                          29.58               10           8.0
# 34                          30.01               10           7.0
# 46                          29.90               10           5.0
#
#             PrecipitationIn  CloudCover    Events  WindDirDegrees
# Temperature
# 38                        0           5       NaN             281
# 36                        0           3       NaN             275
# 40                        0           1       NaN             277
# 25                        0           3       NaN             345
# 20                        0           0       NaN             333
# 33                        0           0       NaN             259
# 39                        0           3       NaN             293
# 39                        0           8       NaN              79
# 44                        T           8      Rain              76
# 50                      1.8           7      Rain             109
# 33                        0           1       NaN             289
# 35                        T           4       NaN             235
# 26                        0           0       NaN             284
# 30                        T           7       NaN             266
# 43                        T           2       NaN             101
# 47                     0.24           7      Rain             340
# 36                     0.05           6  Fog-Snow             345
# 25                        T           2      Snow             293
# 22                        0           1       NaN             293
# 32                        0           2       NaN             302
# 31                        0           1       NaN             312
# 26                     0.01           3      Snow              34
# 26                     2.31           8  Fog-Snow              42
# 28                        T           3      Snow             327
# 34                        0           2       NaN             286
# 43                        0           2       NaN             244
# 41                        T           3      Rain             311
# 37                        0           1       NaN             234
# 36                        0           4       NaN             298
# 34                        0           0       NaN             257
# 46                        0           0       NaN             241

# %%
df.loc['28']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '28'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df.loc['28']
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '28'

# %%
df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/z4/sqpgvldj0m31m5vm_t67ly3r0000gn/T/ipykernel_43142/136303746.py in ?()
# ----> 1 df.reset_index(inplace=True)
#
# ~/myenv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~/myenv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
df
# Out:
#     Temperature  level_0  index        EST  DewPoint  Humidity  \
# 0            38        0      0   1/1/2016        23        52
# 1            36        1      1   1/2/2016        18        46
# 2            40        2      2   1/3/2016        21        47
# 3            25        3      3   1/4/2016         9        44
# 4            20        4      4   1/5/2016        -3        41
# 5            33        5      5   1/6/2016         4        35
# 6            39        6      6   1/7/2016        11        33
# 7            39        7      7   1/8/2016        29        64
# 8            44        8      8   1/9/2016        38        77
# 9            50        9      9  1/10/2016        46        71
# 10           33       10     10  1/11/2016         8        37
# 11           35       11     11  1/12/2016        15        53
# 12           26       12     12  1/13/2016         4        42
# 13           30       13     13  1/14/2016        12        47
# 14           43       14     14  1/15/2016        31        62
# 15           47       15     15  1/16/2016        37        70
# 16           36       16     16  1/17/2016        23        66
# 17           25       17     17  1/18/2016         6        53
# 18           22       18     18  1/19/2016         3        42
# 19           32       19     19  1/20/2016        15        49
# 20           31       20     20  1/21/2016        11        45
# 21           26       21     21  1/22/2016         6        41
# 22           26       22     22  1/23/2016        21        78
# 23           28       23     23  1/24/2016        11        53
# 24           34       24     24  1/25/2016        18        54
# 25           43       25     25  1/26/2016        29        56
# 26           41       26     26  1/27/2016        22        45
# 27           37       27     27  1/28/2016        20        51
# 28           36       28     28  1/29/2016        21        50
# 29           34       29     29  1/30/2016        16        46
# 30           46       30     30  1/31/2016        28        52
#
#     Sea Level PressureIn  VisibilityMiles  WindSpeedMPH PrecipitationIn  \
# 0                  30.03               10           8.0               0
# 1                  30.02               10           7.0               0
# 2                  29.86               10           8.0               0
# 3                  30.05               10           9.0               0
# 4                  30.57               10           5.0               0
# 5                  30.50               10           4.0               0
# 6                  30.28               10           2.0               0
# 7                  30.20               10           4.0               0
# 8                  30.16                9           8.0               T
# 9                  29.59                4           NaN             1.8
# 10                 29.92               10           NaN               0
# 11                 29.85               10           6.0               T
# 12                 29.94               10          10.0               0
# 13                 29.95               10           5.0               T
# 14                 29.82                9           5.0               T
# 15                 29.52                8           7.0            0.24
# 16                 29.78                8           6.0            0.05
# 17                 29.83                9          12.0               T
# 18                 30.03               10          11.0               0
# 19                 30.13               10           6.0               0
# 20                 30.15               10           6.0               0
# 21                 30.21                9           NaN            0.01
# 22                 29.77                1          16.0            2.31
# 23                 29.92                8           6.0               T
# 24                 30.25               10           3.0               0
# 25                 30.03               10           7.0               0
# 26                 30.03               10           7.0               T
# 27                 29.90               10           5.0               0
# 28                 29.58               10           8.0               0
# 29                 30.01               10           7.0               0
# 30                 29.90               10           5.0               0
#
#     CloudCover    Events  WindDirDegrees
# 0            5       NaN             281
# 1            3       NaN             275
# 2            1       NaN             277
# 3            3       NaN             345
# 4            0       NaN             333
# 5            0       NaN             259
# 6            3       NaN             293
# 7            8       NaN              79
# 8            8      Rain              76
# 9            7      Rain             109
# 10           1       NaN             289
# 11           4       NaN             235
# 12           0       NaN             284
# 13           7       NaN             266
# 14           2       NaN             101
# 15           7      Rain             340
# 16           6  Fog-Snow             345
# 17           2      Snow             293
# 18           1       NaN             293
# 19           2       NaN             302
# 20           1       NaN             312
# 21           3      Snow              34
# 22           8  Fog-Snow              42
# 23           3      Snow             327
# 24           2       NaN             286
# 25           2       NaN             244
# 26           3      Rain             311
# 27           1       NaN             234
# 28           4       NaN             298
# 29           0       NaN             257
# 30           0       NaN             241

# %%
df.set_index('VisibilityMiles', inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/z4/sqpgvldj0m31m5vm_t67ly3r0000gn/T/ipykernel_43142/3057380381.py in ?()
# ----> 1 df.set_index('VisibilityMiles', inplace=True)
#       2 df
#
# ~/myenv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['VisibilityMiles'] are in the columns"

# %%
df
# Out:
#                  Temperature  level_0  index        EST  DewPoint  Humidity  \
# VisibilityMiles
# 10                        38        0      0   1/1/2016        23        52
# 10                        36        1      1   1/2/2016        18        46
# 10                        40        2      2   1/3/2016        21        47
# 10                        25        3      3   1/4/2016         9        44
# 10                        20        4      4   1/5/2016        -3        41
# 10                        33        5      5   1/6/2016         4        35
# 10                        39        6      6   1/7/2016        11        33
# 10                        39        7      7   1/8/2016        29        64
# 9                         44        8      8   1/9/2016        38        77
# 4                         50        9      9  1/10/2016        46        71
# 10                        33       10     10  1/11/2016         8        37
# 10                        35       11     11  1/12/2016        15        53
# 10                        26       12     12  1/13/2016         4        42
# 10                        30       13     13  1/14/2016        12        47
# 9                         43       14     14  1/15/2016        31        62
# 8                         47       15     15  1/16/2016        37        70
# 8                         36       16     16  1/17/2016        23        66
# 9                         25       17     17  1/18/2016         6        53
# 10                        22       18     18  1/19/2016         3        42
# 10                        32       19     19  1/20/2016        15        49
# 10                        31       20     20  1/21/2016        11        45
# 9                         26       21     21  1/22/2016         6        41
# 1                         26       22     22  1/23/2016        21        78
# 8                         28       23     23  1/24/2016        11        53
# 10                        34       24     24  1/25/2016        18        54
# 10                        43       25     25  1/26/2016        29        56
# 10                        41       26     26  1/27/2016        22        45
# 10                        37       27     27  1/28/2016        20        51
# 10                        36       28     28  1/29/2016        21        50
# 10                        34       29     29  1/30/2016        16        46
# 10                        46       30     30  1/31/2016        28        52
#
#                  Sea Level PressureIn  WindSpeedMPH PrecipitationIn  \
# VisibilityMiles
# 10                              30.03           8.0               0
# 10                              30.02           7.0               0
# 10                              29.86           8.0               0
# 10                              30.05           9.0               0
# 10                              30.57           5.0               0
# 10                              30.50           4.0               0
# 10                              30.28           2.0               0
# 10                              30.20           4.0               0
# 9                               30.16           8.0               T
# 4                               29.59           NaN             1.8
# 10                              29.92           NaN               0
# 10                              29.85           6.0               T
# 10                              29.94          10.0               0
# 10                              29.95           5.0               T
# 9                               29.82           5.0               T
# 8                               29.52           7.0            0.24
# 8                               29.78           6.0            0.05
# 9                               29.83          12.0               T
# 10                              30.03          11.0               0
# 10                              30.13           6.0               0
# 10                              30.15           6.0               0
# 9                               30.21           NaN            0.01
# 1                               29.77          16.0            2.31
# 8                               29.92           6.0               T
# 10                              30.25           3.0               0
# 10                              30.03           7.0               0
# 10                              30.03           7.0               T
# 10                              29.90           5.0               0
# 10                              29.58           8.0               0
# 10                              30.01           7.0               0
# 10                              29.90           5.0               0
#
#                  CloudCover    Events  WindDirDegrees
# VisibilityMiles
# 10                        5       NaN             281
# 10                        3       NaN             275
# 10                        1       NaN             277
# 10                        3       NaN             345
# 10                        0       NaN             333
# 10                        0       NaN             259
# 10                        3       NaN             293
# 10                        8       NaN              79
# 9                         8      Rain              76
# 4                         7      Rain             109
# 10                        1       NaN             289
# 10                        4       NaN             235
# 10                        0       NaN             284
# 10                        7       NaN             266
# 9                         2       NaN             101
# 8                         7      Rain             340
# 8                         6  Fog-Snow             345
# 9                         2      Snow             293
# 10                        1       NaN             293
# 10                        2       NaN             302
# 10                        1       NaN             312
# 9                         3      Snow              34
# 1                         8  Fog-Snow              42
# 8                         3      Snow             327
# 10                        2       NaN             286
# 10                        2       NaN             244
# 10                        3      Rain             311
# 10                        1       NaN             234
# 10                        4       NaN             298
# 10                        0       NaN             257
# 10                        0       NaN             241

# %%
df.loc['10']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '10'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 df.loc['10']
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/myenv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '10'

# %%
df.loc[10]
# Out:
#                  Temperature  level_0  index        EST  DewPoint  Humidity  \
# VisibilityMiles
# 10                        38        0      0   1/1/2016        23        52
# 10                        36        1      1   1/2/2016        18        46
# 10                        40        2      2   1/3/2016        21        47
# 10                        25        3      3   1/4/2016         9        44
# 10                        20        4      4   1/5/2016        -3        41
# 10                        33        5      5   1/6/2016         4        35
# 10                        39        6      6   1/7/2016        11        33
# 10                        39        7      7   1/8/2016        29        64
# 10                        33       10     10  1/11/2016         8        37
# 10                        35       11     11  1/12/2016        15        53
# 10                        26       12     12  1/13/2016         4        42
# 10                        30       13     13  1/14/2016        12        47
# 10                        22       18     18  1/19/2016         3        42
# 10                        32       19     19  1/20/2016        15        49
# 10                        31       20     20  1/21/2016        11        45
# 10                        34       24     24  1/25/2016        18        54
# 10                        43       25     25  1/26/2016        29        56
# 10                        41       26     26  1/27/2016        22        45
# 10                        37       27     27  1/28/2016        20        51
# 10                        36       28     28  1/29/2016        21        50
# 10                        34       29     29  1/30/2016        16        46
# 10                        46       30     30  1/31/2016        28        52
#
#                  Sea Level PressureIn  WindSpeedMPH PrecipitationIn  \
# VisibilityMiles
# 10                              30.03           8.0               0
# 10                              30.02           7.0               0
# 10                              29.86           8.0               0
# 10                              30.05           9.0               0
# 10                              30.57           5.0               0
# 10                              30.50           4.0               0
# 10                              30.28           2.0               0
# 10                              30.20           4.0               0
# 10                              29.92           NaN               0
# 10                              29.85           6.0               T
# 10                              29.94          10.0               0
# 10                              29.95           5.0               T
# 10                              30.03          11.0               0
# 10                              30.13           6.0               0
# 10                              30.15           6.0               0
# 10                              30.25           3.0               0
# 10                              30.03           7.0               0
# 10                              30.03           7.0               T
# 10                              29.90           5.0               0
# 10                              29.58           8.0               0
# 10                              30.01           7.0               0
# 10                              29.90           5.0               0
#
#                  CloudCover Events  WindDirDegrees
# VisibilityMiles
# 10                        5    NaN             281
# 10                        3    NaN             275
# 10                        1    NaN             277
# 10                        3    NaN             345
# 10                        0    NaN             333
# 10                        0    NaN             259
# 10                        3    NaN             293
# 10                        8    NaN              79
# 10                        1    NaN             289
# 10                        4    NaN             235
# 10                        0    NaN             284
# 10                        7    NaN             266
# 10                        1    NaN             293
# 10                        2    NaN             302
# 10                        1    NaN             312
# 10                        2    NaN             286
# 10                        2    NaN             244
# 10                        3   Rain             311
# 10                        1    NaN             234
# 10                        4    NaN             298
# 10                        0    NaN             257
# 10                        0    NaN             241
